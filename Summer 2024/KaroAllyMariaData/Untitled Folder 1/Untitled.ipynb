# %%
#liz stacy ethan code
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import datetime
import os

col_names = ["Index", "DateD", "DateM", "DateY", "Time", "MonStatus", "Extras", "MonN", "TubeN", "DataType", "Unused", "Light"]

for i in range(1, 33):
    col_names.append(f"Sp{i}")

file = 'A10AM.csv'

df = pd.read_csv(file, names=col_names, sep='\s+', header=None)
print(df)
df = df.set_index('Index')
display(df)
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce')
display(df)
df = df[df["MonStatus"] == 1]

display(df)
month_map = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6}
df['DateM'] = df['DateM'].str[:3].map(month_map)
#print(df['DateM'].
df['DateY'] = df['DateY'].apply(lambda x: int(str(20) + str(x)))
df['Date'] = pd.to_datetime(dict(year=df['DateY'], month=df['DateM'], day=df['DateD']), errors='coerce')

df['Time'] = pd.to_datetime(dict(year=df['Date'].dt.year,
                                     month=df['Date'].dt.month,
                                     day=df['Date'].dt.day,
                                     hour=df['Time'].dt.hour,
                                     minute=df['Time'].dt.minute,
                                     second=df['Time'].dt.second))

df = df.drop(["DateD", "DateM", "DateY", "Date", "MonStatus", "Extras", "MonN", "TubeN", "DataType", "Unused"], axis=1)

day_map = {day: idx+1 for idx, day in enumerate(df['Time'].dt.day.unique())}

df.insert(0, 'Day', df['Time'].dt.day.map(day_map))

#df.to_csv('steatodaA.csv')
display(df)
# Out:
#                                                   Index  DateD  DateM  DateY  \
# 0     1\t7 Mar 24\t10:34:00\t1\t0\t1\t0\tCt\t0\t1\t0...    NaN    NaN    NaN
# 1     2\t7 Mar 24\t10:35:00\t1\t0\t1\t0\tCt\t0\t1\t0...    NaN    NaN    NaN
# 2     3\t7 Mar 24\t10:36:00\t1\t0\t1\t0\tCt\t0\t1\t0...    NaN    NaN    NaN
# 3     4\t7 Mar 24\t10:37:00\t1\t0\t1\t0\tCt\t0\t1\t0...    NaN    NaN    NaN
# 4     5\t7 Mar 24\t10:38:00\t1\t0\t1\t0\tCt\t0\t1\t0...    NaN    NaN    NaN
# ...                                                 ...    ...    ...    ...
# 9080  9081\t13 Mar 24\t18:54:00\t1\t0\t1\t0\tCt\t0\t...    NaN    NaN    NaN
# 9081  9082\t13 Mar 24\t18:55:00\t1\t0\t1\t0\tCt\t0\t...    NaN    NaN    NaN
# 9082  9083\t13 Mar 24\t18:56:00\t1\t0\t1\t0\tCt\t0\t...    NaN    NaN    NaN
# 9083  9084\t13 Mar 24\t18:57:00\t1\t0\t1\t0\tCt\t0\t...    NaN    NaN    NaN
# 9084  9085\t13 Mar 24\t18:58:00\t1\t0\t1\t0\tCt\t0\t...    NaN    NaN    NaN
#
#       Time  MonStatus  Extras  MonN  TubeN  DataType  ...  Sp23  Sp24  Sp25  \
# 0      NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 1      NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 2      NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 3      NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 4      NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# ...    ...        ...     ...   ...    ...       ...  ...   ...   ...   ...
# 9080   NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 9081   NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 9082   NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 9083   NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
# 9084   NaN        NaN     NaN   NaN    NaN       NaN  ...   NaN   NaN   NaN
#
#       Sp26  Sp27  Sp28  Sp29  Sp30  Sp31  Sp32
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...
# 9080   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9081   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9082   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9083   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9084   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [9085 rows x 44 columns]
#                                                     DateD  DateM  DateY  Time  \
# Index
# 1\t7 Mar 24\t10:34:00\t1\t0\t1\t0\tCt\t0\t1\t0\...    NaN    NaN    NaN   NaN
# 2\t7 Mar 24\t10:35:00\t1\t0\t1\t0\tCt\t0\t1\t0\...    NaN    NaN    NaN   NaN
# 3\t7 Mar 24\t10:36:00\t1\t0\t1\t0\tCt\t0\t1\t0\...    NaN    NaN    NaN   NaN
# 4\t7 Mar 24\t10:37:00\t1\t0\t1\t0\tCt\t0\t1\t0\...    NaN    NaN    NaN   NaN
# 5\t7 Mar 24\t10:38:00\t1\t0\t1\t0\tCt\t0\t1\t0\...    NaN    NaN    NaN   NaN
# ...                                                   ...    ...    ...   ...
# 9081\t13 Mar 24\t18:54:00\t1\t0\t1\t0\tCt\t0\t1...    NaN    NaN    NaN   NaN
# 9082\t13 Mar 24\t18:55:00\t1\t0\t1\t0\tCt\t0\t1...    NaN    NaN    NaN   NaN
# 9083\t13 Mar 24\t18:56:00\t1\t0\t1\t0\tCt\t0\t1...    NaN    NaN    NaN   NaN
# 9084\t13 Mar 24\t18:57:00\t1\t0\t1\t0\tCt\t0\t1...    NaN    NaN    NaN   NaN
# 9085\t13 Mar 24\t18:58:00\t1\t0\t1\t0\tCt\t0\t1...    NaN    NaN    NaN   NaN
#
#                                                     MonStatus  Extras  MonN  \
# Index
# 1\t7 Mar 24\t10:34:00\t1\t0\t1\t0\tCt\t0\t1\t0\...        NaN     NaN   NaN
# 2\t7 Mar 24\t10:35:00\t1\t0\t1\t0\tCt\t0\t1\t0\...        NaN     NaN   NaN
# 3\t7 Mar 24\t10:36:00\t1\t0\t1\t0\tCt\t0\t1\t0\...        NaN     NaN   NaN
# 4\t7 Mar 24\t10:37:00\t1\t0\t1\t0\tCt\t0\t1\t0\...        NaN     NaN   NaN
# 5\t7 Mar 24\t10:38:00\t1\t0\t1\t0\tCt\t0\t1\t0\...        NaN     NaN   NaN
# ...                                                       ...     ...   ...
# 9081\t13 Mar 24\t18:54:00\t1\t0\t1\t0\tCt\t0\t1...        NaN     NaN   NaN
# 9082\t13 Mar 24\t18:55:00\t1\t0\t1\t0\tCt\t0\t1...        NaN     NaN   NaN
# 4\t7 Mar 24\t10:37:00\t1\t0\t1\t0\tCt\t0\t1\t0\...   NaN   NaN   NaN
# 5\t7 Mar 24\t10:38:00\t1\t0\t1\t0\tCt\t0\t1\t0\...   NaN   NaN   NaN
# ...                                                  ...   ...   ...
# 9081\t13 Mar 24\t18:54:00\t1\t0\t1\t0\tCt\t0\t1...   NaN   NaN   NaN
# 9082\t13 Mar 24\t18:55:00\t1\t0\t1\t0\tCt\t0\t1...   NaN   NaN   NaN
# 9083\t13 Mar 24\t18:56:00\t1\t0\t1\t0\tCt\t0\t1...   NaN   NaN   NaN
# 9084\t13 Mar 24\t18:57:00\t1\t0\t1\t0\tCt\t0\t1...   NaN   NaN   NaN
# 9085\t13 Mar 24\t18:58:00\t1\t0\t1\t0\tCt\t0\t1...   NaN   NaN   NaN
#
# [9085 rows x 43 columns]
# Empty DataFrame
# Columns: [DateD, DateM, DateY, Time, MonStatus, Extras, MonN, TubeN, DataType, Unused, Light, Sp1, Sp2, Sp3, Sp4, Sp5, Sp6, Sp7, Sp8, Sp9, Sp10, Sp11, Sp12, Sp13, Sp14, Sp15, Sp16, Sp17, Sp18, Sp19, Sp20, Sp21, Sp22, Sp23, Sp24, Sp25, Sp26, Sp27, Sp28, Sp29, Sp30, Sp31, Sp32]
# Index: []
#
# [0 rows x 43 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 25
#      23 display(df)
#      24 month_map = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6}
# ---> 25 df['DateM'] = df['DateM'].str[:3].map(month_map)
#      26 #print(df['DateM'].
#      27 df['DateY'] = df['DateY'].apply(lambda x: int(str(20) + str(x)))
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/pandas/core/strings/accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/pandas/core/strings/accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!
