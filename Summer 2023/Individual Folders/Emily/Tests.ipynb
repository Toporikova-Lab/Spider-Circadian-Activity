# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
series = read_csv('Practice 3_data1.csv')
X = series.s2
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -12.297673
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
from scipy.fft import fft, ifft

# %%
import numpy as np
x = series.s2
y = fft(x)
plt.plot(np.abs(y))

# %%
yinv = ifft(y)
yinv
# Out:
# array([ 3.00000000e+00+2.89638248e-16j,  3.00000000e+00-4.03307598e-16j,
#         1.00000000e+00+6.20809528e-16j, ...,
#         1.22413146e-15-6.04862599e-16j, -4.61781735e-17+5.98325594e-17j,
#         3.41882430e-15-4.08303319e-16j])

# %%
from scipy.fft import fft, fftfreq
import numpy as np
# Number of sample points
N = len(series.s2)
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)
xf = fftfreq(N, T)[:N//2]
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
#Fourier Transform
Importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating input array
arr = series.s2

# Creating sine-value Fourier transforms
sine_vals = np.fft.fft(np.sin(arr))

# Creating frequency array of sine-value Fourier transforms
frequency = np.fft.fftfreq(arr.shape[-1])

# Plotting the real and imaginary parts
plt.plot(frequency, sine_vals.real, frequency, sine_vals.imag)
plt.show()

# %%
scipy.signal.periodogram(series.s2)
# Out:
# (array([0.00000000e+00, 3.84556222e-05, 7.69112444e-05, ...,
#         4.99923089e-01, 4.99961544e-01, 5.00000000e-01]),
#  array([6.80430330e-28, 1.08434589e+03, 1.70664127e+02, ...,
#         8.42417774e-01, 4.95086790e+00, 6.33887094e+00]))

# %%
# power spectral density
plt.psd(series.s2)
plt.show()
