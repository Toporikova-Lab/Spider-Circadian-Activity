# %%
#Import relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualizing Spider activity experiment

# %% [markdown]
# Download data from the file **Metazygia monitor 1.csv**. Make a date column a [date-time index](https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.html). If you not sure what the date-time index is, read [this book chapter](https://wesmckinney.com/book/time-series). You shoudl have a time-stamp index, a light column and 32 column for individual spider activity. It shoudl look like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This data file was extracted from the data collected by activity monitor. The activity collecting softward is actually gives you a .txt file 42 column. Below is a snapshot from the monitor documentation which describe variable collected in each column:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For your convenience, the information about all the channels in the monitor is provided to you in the file **monitor channels info.csv**.  Use this information to import experimental file **Metazygia monitor 1.txt** into a data frame. This is an original experimental file which has been used to generate .csv file above.  For our experimental purposes we wil be only collecting information about time, light, and spider activity. Let's import the data from **Metazygia monitor 1.txt** into a data frame, keep the timestamp as date-time index and remove all the columns which is not used in the experiment (4-9). you should have a data frame like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Experiment 1: Pre-processing

# %% [markdown]
#    - Print out the date and times for the beginnigng and end of the experient
#    - Print out the number of days in the experiment

# %% [markdown]
# For illustrative purposes, it would be better if we do not have incomplete days. However, we do not want to lose data, so the common approach is to fill incompleted days with NaNs. Write a function which takes your experimental dataframe and add NaN values for incomplete days (both, in thebeginnign and end of the experiment). Make a simple plot for one spider to confirn that your data are not affected. Basically, you should have a x-axis lasts full days, but there should be no graph at the times you padded with NaNs.

# %% [markdown]
# ## Experiment 2: Explore first full day

# %% [markdown]
# Write a function which takes a dataframe with light and activity column and make an activity graph, where the dark time oof the day (light indicator =0) is shaded in grey.Test your funciton on first day of spider s2. Your graph should look something like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculate the mean and standard deviation of activity. Experiment with ranges of y-axis to expand it to several standard deviation from the mean. What STD range give you view for optimal analysis of the activity.  Experiment with activiy of other spiders in the data frame. Select the STD range which works for all spiders (if possible). If not possible, try to think how would you adjust the y-range. Your goal is to write a code to batch processing activity visualization for all spiders in the data set.

# %% [markdown]
# ## Experiment 3: Raster plot for multiple days

# %% [markdown]
# Make a raster plot function which take an data frame consisting from light and one spider activity column and return the raster plot with the dark period shaded.The days should be stacked on the top of each other (early time first). Test your function on spider s3.

# %% [markdown]
# Use your funciton to generate raster plots for all spiders in a data sets. Save raster plots as .png images. The name of the image shoudl be a predictable combination of name of experiment, spider ID and word "raster". The script below should generate 32 graphs with axis adjusted to provide optimal activity illustration for each spider.

# %% [markdown]
# ## Experiment 4: Separate raster to LD and DD period

# %% [markdown]
# The full raster plot for the experiment is essential for initial visual inspection of activity. However, our goal is to compare activity of our spiders in a similar condition. Thus, it is essential to split our data in LD and DD regime. Write a funciton which take full data frame of activity and return two separate data frame - one for LD another for DD. Test your function on spider S3 by making separate raster plots for LD and DD data frames.

# %% [markdown]
# ## Experiment 5: Compare Activity of different spiders

# %% [markdown]
# Congradulation of making a complex visualization for large number of spiders! If you look at the individual raster plots you have created, you will notice that the pattern of acitivity is quite different among the subjects. It is a great observation, but in science visual observation is not enought to reach the conclusion. In this experiment you can use your creativity and background on scientific experimentation to conduct QUANTITATIVE analysis of animal free running behavior. Conduct informative quantitative ananlysis supported by visualizaiton to provide comparison of locomotive behavior among the spiders.  In the space below please compose a brief report on this comparative analysis. Your report should include
#  -  Biological rational on variatinon in free running periods.
#      - You should use at least 3 peer-review sources
#  - An optimal visualization which compares/summarizes LD activity among all alive spiders
#  - Am optimal visualization which compares/summarizes DD activity among all alive spiders
#  - Quantitative comparison of locomotor activity in LD and DD tables and/or visualization
#  - Your interpretation of table/visualization above
#  - Conclusion section where you logically explain the similarity/differences among the spiders
