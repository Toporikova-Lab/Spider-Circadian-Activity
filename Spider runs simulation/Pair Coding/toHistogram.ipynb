# %% [markdown]
# # Import libraries and read CSV file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta

#Read Spider activity CSV file
filename = 'Metazygia wittfeldae Monitor 1 activity_DD_reindex_binary_run_duration'
df = pd.read_csv(filename + '.csv', index_col = 0)
df
# Out:
#       s1    s2    s3   s4   s5    s6    s7   s8   s9  s10  ...   s23  s24  \
# 0    6.0   3.0   4.0  8.0  2.0   2.0  17.0  2.0  3.0  7.0  ...  36.0  7.0
# 1    1.0  17.0  10.0  2.0  1.0   4.0  14.0  1.0  3.0  7.0  ...  29.0  6.0
# 2    6.0   3.0   1.0  5.0  3.0   8.0   6.0  1.0  3.0  2.0  ...   2.0  2.0
# 3    4.0   8.0   2.0  5.0  5.0  27.0   1.0  4.0  1.0  2.0  ...  19.0  6.0
# 4    7.0   2.0   5.0  1.0  1.0   1.0  16.0  2.0  1.0  2.0  ...   2.0  1.0
# ..   ...   ...   ...  ...  ...   ...   ...  ...  ...  ...  ...   ...  ...
# 567  NaN   NaN   NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN  NaN
# 568  NaN   NaN   NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN  NaN
# 569  NaN   NaN   NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN  NaN
# 570  NaN   NaN   NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN  NaN
# 571  NaN   NaN   NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN  NaN
#
#      s25  s26   s27  s28   s29   s30  s31  s32
# ...

# %% [markdown]
# # Drop Columns

# %% [markdown]
# Drop columns that only have NaN values (depending on the CSV file)

# %%
#df1 = df.copy()
#df1 = df1.drop(columns = ['s26', 's28'])

# %% [markdown]
# # Create Histogram

# %% [markdown]
# Creates histogram of all spider run durations with fixed axes added manually.

# %%
def draw_histogram(col):    
    plt.title(col + ' DD Run Duration Distribution')
    plt.xlabel('Run Duration')
    plt.ylabel('Count')
    #maxDuration = df1.max().max()
    #maxCounts = df1.idxmax()
    #maxCount = maxCounts.max()
    plt.grid(True)
    plt.xlim(0, 50)
    plt.ylim(0, 500)
    #plt.xlim(0, maxDuration + 10)
    #plt.ylim(0, maxCount * 1.5)

# %% [markdown]
# # Show Histograms

# %% [markdown]
# Shows all spider run duration histograms

# %%
def show_all_histograms(df):
    for i, col in enumerate(df.columns):
        plt.figure(i)
        plt.hist(df[col])
    
        draw_histogram(col)
        
        plt.savefig(col + ".jpeg")
        
show_all_histograms(df)
# Out:
# /var/folders/jt/ss6zd2nx0bv4h_3q_d2qtldm0000gn/T/ipykernel_52300/1929997339.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(i)
