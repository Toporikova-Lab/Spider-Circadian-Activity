# %%
#pip install boxsdk

# %%
from boxsdk import JWTAuth, Client

config = JWTAuth.from_settings_file('/Users/hannahburke/Downloads/config.json')

# %%
client = Client(config)

# %%
file_id = '917371196562'
file_content = client.file(file_id).content()
# Out:
# "POST https://api.box.com/oauth2/token" 400 104
# {'Date': 'Mon, 23 May 2022 19:59:22 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=31536000', 'Set-Cookie': 'box_visitor_id=628be799f03157.63682990; expires=Tue, 23-May-2023 19:59:21 GMT; Max-Age=31536000; path=/; domain=.box.com; secure, bv=OPS-45240; expires=Mon, 30-May-2022 19:59:21 GMT; Max-Age=604800; path=/; domain=.app.box.com; secure, cn=12; expires=Tue, 23-May-2023 19:59:21 GMT; Max-Age=31536000; path=/; domain=.app.box.com; secure, site_preference=desktop; path=/; domain=.box.com; secure', 'Cache-Control': 'no-store'}
# {'error': 'unauthorized_client',
#  'error_description': 'This app is not authorized by the enterprise admin'}
# ---------------------------------------------------------------------------
# BoxAPIException                           Traceback (most recent call last)
# ...
